# %% [markdown]
# # Worldwide Earthquake Events API - Gold Layer Processing

# %%
from pyspark.sql.functions import when, col, udf
from pyspark.sql.types import StringType
# ensure the below library is installed on your fabric environment
import reverse_geocoder as rg
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 7, Finished, Available, Finished, False)

# %%
df = spark.read.table("earthquake_events_silver").filter(col('time') > start_date)
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 9, Finished, Available, Finished, False)

# %%
#cord=(54.5813,-160.0972)
#rg.search(cord)[0]['cc']    #how geo_encoder library works.

# %%
display(df)

# %%
def get_country_code(lat, lon):
    """
    Retrieve the country code for a given latitude and longitude.

    Parameters:
    lat (float or str): Latitude of the location.
    lon (float or str): Longitude of the location.

    Returns:
    str: Country code of the location, retrieved using the reverse geocoding API.

    Example:
    >>> get_country_details(48.8588443, 2.2943506)
    'FR'
    """
    coordinates = (float(lat), float(lon))
    return rg.search(coordinates)[0].get('cc')
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 14, Finished, Available, Finished, False)

# %%
# registering the udfs so they can be used on spark dataframes
get_country_code_udf = udf(get_country_code, StringType())
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 15, Finished, Available, Finished, False)

# %%
# adding country_code and city attributes
df_with_location = \
                df.\
                    withColumn("country_code", get_country_code_udf(col("latitude"), col("longitude")))
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 20, Finished, Available, Finished, False)

# %%
display(df_with_location)

# %%
# adding significance classification
df_with_location_sig_class = \
                            df_with_location.\
                                withColumn('sig_class', 
                                            when(col("sig") < 100, "Low").\
                                            when((col("sig") >= 100) & (col("sig") < 500), "Moderate").\
                                            otherwise("High")
                                            )
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 29, Finished, Available, Finished, False)

# %%
display(df_with_location_sig_class)

# %%
# appending the data to the gold table
df_with_location_sig_class.write.mode('append').saveAsTable('earthquake_events_gold')
# Out:
# StatementMeta(, 30022a3f-2e2c-4b4a-b657-dab3e4bcffd5, 33, Finished, Available, Finished, False)
