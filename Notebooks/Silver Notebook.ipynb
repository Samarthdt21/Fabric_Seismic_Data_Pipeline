# %% [markdown]
# # Worldwide Earthquake Events API - Silver Layer Processing

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 8, Finished, Available, Finished, False)

# %%
#from datetime import date, timedelta   
#start_date= date.today() - timedelta(7)
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 9, Finished, Available, Finished, False)

# %%
# df now is a Spark DataFrame containing JSON data
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 10, Finished, Available, Finished, False)

# %%
display(df)
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, fa7d9f76-1e4d-4959-9b4a-d09920861a4a)

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis.
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 12, Finished, Available, Finished, False)

# %%
display(df)
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 13, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 34e3af92-52e8-4687-9619-bd18dcea958f)

# %%
# Convert 'time' and 'updated' columns from unix timestamp milliseconds to timestamp format for clearer datetime representation. 
# Divide by 1000 to convert to second
df = df.withColumn("time", col("time") / 1000) \
       .withColumn("updated", col("updated") / 1000) \
       .withColumn("time", col("time").cast(TimestampType())) \
       .withColumn("updated", col("updated").cast(TimestampType()))
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 19, Finished, Available, Finished, False)

# %%
display(df)

# %%
# appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, e9906fae-e442-4d3b-aaa8-bef1aa30b239, 21, Finished, Available, Finished, False)
